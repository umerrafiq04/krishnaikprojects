# %% [markdown]
# Named Entity Recognition is the process of identifying and classifying important real-world entities in a text such as:
#
# 🧑 Person names
#
# 🌍 Locations
#
# 🏢 Organizations
#
# 📅 Dates
#
# 💸 Monetary values
#
# 🔢 Percentages, etc.

# %%
import nltk
sentence="Dr. A.P.J. Abdul Kalam was born in Rameswaram, India on October 15, 1931."
"Dr. A.P.J. Abdul Kalam was born in Rameswaram, India on October 15, 1931."
# Out:
# 'Dr. A.P.J. Abdul Kalam was born in Rameswaram, India on October 15, 1931.'

# %%
words=nltk.word_tokenize(sentence)
words
# Out:
# ['Dr.',
#  'A.P.J',
#  '.',
#  'Abdul',
#  'Kalam',
#  'was',
#  'born',
#  'in',
#  'Rameswaram',
#  ',',
#  'India',
#  'on',
#  'October',
#  '15',
#  ',',
#  '1931',
#  '.']

# %%
tag_elements=nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# In nltk.ne_chunk(tagged_elements).draw(), the GPE label stands for Geo-Political Entity.countries,cities etc

# %%
nltk.ne_chunk(tag_elements).draw()
